# %% [markdown]
# # Assignment 1 - Advanced Statistics

# %%
# function that lists all possible outcomes for 5 dice
# order doesn't matter: n=6, k=5, number of possible outcomes = (5+6-1)!/(5!(10-5)!) = 252

def getPossibleOutcomes5Dice ():
    numOfDiceRolls = 5
    possibleOutcomes = [[]] # track all the possible outcomes

    # For each time we throw a dice we add all the possible outcomes (1-6) to the already calculated (intermediate) outcome
    # this is an iterative approach (another approach would be a recursive function)
    for throw in range(numOfDiceRolls):
        # store the intermediate outcomes in a temporary copy
        possibleOutcomesCopy = possibleOutcomes.copy()
        possibleOutcomes = [] 
        for intermediateOutcome in possibleOutcomesCopy:
            for outcome in [1,2,3,4,5,6]:
                # all possible outcomes of one dice roll are appended to the intermediate Outcome 
                possibleOutcomes.append(intermediateOutcome + [outcome])
    # if the order of dice would matter we would have 7776 possible outcomes
    print("Number of possible outcomes (with order):", len(possibleOutcomes))
        
    # return a subset of the total number of outcomes excluding the permutations of each combination because order doesn't matter
    print("Number of possible outcomes (without order):",len(list(set(tuple(sorted(subset)) for subset in possibleOutcomes))))
    return(list(set(tuple(sorted(subset)) for subset in possibleOutcomes)))
            
    
getPossibleOutcomes5Dice()
# Out:
# Number of possible outcomes (with order): 7776
# Number of possible outcomes (without order): 252
# [(1, 1, 1, 2, 3),
#  (3, 5, 6, 6, 6),
#  (5, 5, 5, 5, 6),
#  (1, 1, 2, 2, 3),
#  (1, 2, 4, 6, 6),
#  (3, 3, 3, 6, 6),
#  (3, 4, 4, 6, 6),
#  (2, 2, 2, 2, 2),
#  (3, 3, 3, 3, 3),
#  (2, 3, 5, 6, 6),
#  (5, 5, 5, 6, 6),
#  (2, 3, 3, 3, 5),
#  (2, 3, 5, 5, 5),
#  (2, 2, 3, 5, 6),
#  (1, 5, 5, 6, 6),
#  (4, 5, 5, 5, 5),
#  (1, 2, 2, 2, 6),
#  (1, 2, 4, 4, 6),
#  (1, 2, 6, 6, 6),
#  (1, 1, 3, 5, 6),
#  (2, 3, 3, 4, 5),
#  (3, 4, 4, 4, 6),
#  (1, 3, 4, 5, 6),
#  (3, 4, 6, 6, 6),
#  (2, 2, 3, 3, 6),
#  (2, 2, 5, 5, 6),
#  (2, 5, 5, 6, 6),
#  (1, 2, 2, 3, 3),
#  (2, 2, 2, 4, 5),
#  (1, 2, 2, 4, 4),
#  (1, 1, 1, 5, 6),
#  (2, 2, 2, 3, 5),
#  (2, 2, 4, 5, 5),
#  (1, 2, 5, 6, 6),
#  (1, 2, 3, 3, 3),
#  (2, 2, 3, 4, 4),
#  (4, 4, 4, 5, 5),
#  (1, 1, 2, 2, 2),
#  (2, 3, 4, 5, 5),
#  (1, 3, 3, 4, 4),
#  (1, 1, 1, 3, 6),
#  (2, 3, 3, 3, 6),
#  (2, 3, 5, 5, 6),
#  (3, 3, 4, 6, 6),
#  (1, 3, 3, 3, 6),
#  (1, 3, 5, 5, 6),
#  (3, 3, 4, 5, 5),
#  (1, 4, 4, 5, 6),
#  (4, 5, 5, 5, 6),
#  (1, 1, 3, 5, 5),
#  (1, 5, 6, 6, 6),
#  (1, 1, 1, 4, 4),
#  (2, 3, 3, 4, 4),
#  (1, 1, 5, 5, 6),
#  (2, 3, 3, 3, 4),
#  (1, 3, 3, 5, 5),
#  (1, 2, 2, 2, 5),
#  (1, 2, 4, 4, 5),
#  (2, 2, 2, 5, 6),
#  (2, 4, 5, 5, 5),
#  (2, 3, 3, 4, 6),
#  (3, 4, 4, 4, 5),
#  (2, 5, 6, 6, 6),
#  (1, 1, 1, 1, 4),
#  (1, 1, 3, 3, 4),
#  (2, 4, 4, 5, 6),
#  (1, 1, 2, 5, 6),
#  (3, 3, 4, 4, 4),
#  (3, 3, 3, 4, 6),
#  (3, 4, 4, 5, 6),
#  (2, 2, 2, 3, 4),
#  (1, 3, 4, 4, 4)]

# %%
# function that gets n dices and returns all the possible outcomes

def getPossibleOutcomes (numOfDiceRolls):
    possibleOutcomes = [[]] # track all the possible outcomes

    # For each time we throw a dice we add all the possible outcomes (1-6) to the already calculated (intermediate) outcome
    # this is an iterative approach (another approach would be a recursive function)
    for throw in range(numOfDiceRolls):
        # store the intermediate outcomes in a temporary copy
        possibleOutcomesCopy = possibleOutcomes.copy()
        possibleOutcomes = [] 
        for intermediateOutcome in possibleOutcomesCopy:
            for outcome in [1,2,3,4,5,6]:
                # all possible outcome
                s of one dice roll are appended to the intermediate Outcome 
                possibleOutcomes.append(intermediateOutcome + [outcome])
    # if the order of dice would matter we would have 7776 possible outcomes
    print("Number of possible outcomes (with order):", len(possibleOutcomes))
        
    # return a subset of the total number of outcomes excluding the permutations of each combination because order doesn't matter
    print("Number of possible outcomes (without order):",len(list(set(tuple(sorted(subset)) for subset in possibleOutcomes))))
    return(list(set(tuple(sorted(subset)) for subset in possibleOutcomes)))
            
# example for the function with 4 dice
getPossibleOutcomes(4)
# Out:
# Number of possible outcomes (with order): 1296
# Number of possible outcomes (without order): 126
# [(2, 5, 6, 6),
#  (4, 4, 4, 6),
#  (3, 4, 4, 4),
#  (2, 4, 4, 6),
#  (2, 4, 4, 5),
#  (1, 4, 4, 5),
#  (3, 3, 3, 5),
#  (3, 3, 3, 6),
#  (3, 3, 3, 3),
#  (1, 2, 6, 6),
#  (1, 4, 6, 6),
#  (1, 1, 2, 2),
#  (1, 1, 2, 5),
#  (1, 2, 2, 4),
#  (2, 2, 3, 4),
#  (5, 5, 5, 5),
#  (3, 5, 6, 6),
#  (2, 2, 5, 5),
#  (2, 2, 5, 6),
#  (1, 3, 4, 4),
#  (2, 6, 6, 6),
#  (3, 3, 4, 4),
#  (1, 1, 5, 5),
#  (1, 1, 1, 6),
#  (1, 1, 1, 3),
#  (2, 3, 4, 4),
#  (3, 4, 5, 6),
#  (1, 4, 5, 6),
#  (3, 6, 6, 6),
#  (2, 2, 2, 4),
#  (1, 2, 5, 5),
#  (1, 4, 5, 5),
#  (2, 2, 2, 3),
#  (5, 5, 6, 6),
#  (2, 2, 6, 6),
#  (1, 3, 3, 6),
#  (1, 3, 3, 3),
#  (1, 3, 5, 5),
#  (4, 4, 6, 6),
#  (1, 3, 5, 6),
#  (2, 2, 4, 5),
#  (2, 3, 3, 6),
#  (3, 3, 5, 5),
#  (2, 3, 3, 5),
#  (1, 1, 6, 6),
#  (4, 4, 4, 5),
#  (3, 4, 4, 5),
#  (3, 4, 4, 6),
#  (2, 4, 4, 4),
#  (1, 4, 4, 6),
#  (2, 2, 3, 3),
#  (1, 1, 2, 4),
#  (1, 2, 2, 5),
#  (2, 2, 3, 5),
#  (1, 2, 2, 2),
#  (1, 2, 4, 4),
#  (5, 5, 5, 6),
#  (2, 3, 5, 6),
#  (4, 5, 5, 6),
#  (2, 5, 5, 6),
#  (2, 5, 5, 5),
#  (1, 3, 4, 6),
#  (1, 6, 6, 6),
#  (1, 5, 6, 6),
#  (1, 1, 5, 6),
#  (1, 1, 1, 4),
#  (3, 3, 6, 6),
#  (1, 1, 1, 1),
#  (1, 1, 3, 4),
#  (2, 4, 5, 5),
#  (2, 3, 4, 5),
#  (3, 4, 5, 5),
#  (2, 3, 4, 6),
#  (2, 2, 2, 2),
#  (1, 5, 5, 5),
#  (1, 2, 3, 3),
#  (4, 5, 6, 6),
#  (1, 2, 3, 6),
#  (1, 2, 3, 5),
#  (6, 6, 6, 6),
#  (1, 3, 3, 4),
#  (1, 1, 4, 6),
#  (2, 2, 4, 4),
#  (1, 1, 4, 5),
#  (3, 4, 6, 6),
#  (3, 3, 5, 6),
#  (2, 3, 3, 4),
#  (4, 4, 4, 4),
#  (2, 3, 3, 3),
#  (1, 4, 4, 4),
#  (3, 3, 3, 4),
#  (2, 4, 6, 6),
#  (1, 1, 2, 3),
#  (1, 2, 2, 6),
#  (1, 1, 2, 6),
#  (2, 2, 3, 6),
#  (1, 2, 4, 5),
#  (1, 2, 2, 3),
#  (1, 2, 4, 6),
#  (2, 3, 5, 5),
#  (1, 3, 6, 6),
#  (4, 5, 5, 5),
#  (1, 3, 4, 5),
#  (3, 3, 4, 6),
#  (3, 3, 4, 5),
#  (1, 1, 1, 5),
#  (1, 1, 1, 2),
#  (4, 4, 5, 5),
#  (2, 3, 6, 6),
#  (1, 1, 3, 5),
#  (4, 4, 5, 6),
#  (2, 4, 5, 6),
#  (1, 1, 3, 6),
#  (1, 1, 3, 3),
#  (4, 6, 6, 6),
#  (2, 2, 2, 6),
#  (2, 2, 2, 5),
#  (1, 2, 5, 6),
#  (3, 5, 5, 5),
#  (3, 5, 5, 6),
#  (1, 5, 5, 6),
#  (1, 2, 3, 4),
#  (1, 3, 3, 5),
#  (5, 6, 6, 6),
#  (1, 1, 4, 4),
#  (2, 2, 4, 6)]

# %%
# functions that return a boolean according to if we have a straight, full, poker or generala

num = [2,3,4,5,6,7]


# first create function that checks if numbers in the list are in between 1 and 6
def isDiceRoll (dices):
    for i in dices:
        if i < 1 or i > 6 :
            return False
    return True



# in each function i first check if the list of "dices" is actually a dice roll, if not give error message
def isStraight (dices):
    if not isDiceRoll (dices) :
        # Error message
    for i in range (0, len(dices)-1):
        if dices[i]+1 != dices[i+1] :
            return False
    return True

def isFull (dices):
     if not isDiceRoll (dices) :
        # Error message
    dices.sort()
    threeCounter = 0
    twoCounter = 0
    for i in range (0, len(dices)-1):
        if dices[i] == dices [i+1] and dices [i+1] == dices :
            return True
        
def isPoker (dices):
     if not isDiceRoll (dices) :
        # Error message
    return False
        
def isGenerala (dices) :
     if not isDiceRoll (dices) :
        # Error message
    for i in range (0, len(dices)-1):
        if dices[i] != dices[i+1] :
            return False
    return True
        
isDiceRoll(num)
# Out:
# False
